# %%
import pandas as pd

# %%
ev = pd.read_csv("EVsales_data/EVsales_data.csv")
ev
# Out:
#          region    category           parameter  mode powertrain  year  \
# 0     Australia  Historical            EV sales  Cars        BEV  2011
# 1     Australia  Historical      EV stock share  Cars         EV  2011
# 2     Australia  Historical      EV sales share  Cars         EV  2011
# 3     Australia  Historical            EV stock  Cars        BEV  2011
# 4     Australia  Historical            EV stock  Cars        BEV  2012
# ...         ...         ...                 ...   ...        ...   ...
# 3793      World  Historical            EV stock  Cars        BEV  2023
# 3794      World  Historical            EV sales  Cars        BEV  2023
# 3795      World  Historical      EV sales share  Cars         EV  2023
# 3796      World  Historical      EV stock share  Cars         EV  2023
# 3797      World  Historical  Electricity demand  Cars         EV  2023
#
#           unit         value
# 0     Vehicles  4.900000e+01
# 1      percent  3.900000e-04
# ...

# %%
ev["parameter"].unique()
# Out:
# array(['EV sales', 'EV stock share', 'EV sales share', 'EV stock',
#        'Electricity demand', 'Oil displacement Mbd',
#        'Oil displacement, million lge'], dtype=object)

# %%
ev["powertrain"].unique()
# Out:
# array(['BEV', 'EV', 'PHEV', 'FCEV'], dtype=object)

# %% [markdown]
# #From the parameter column we will keep the EV sales.
# #we will remove the column category
# #remove world from region column

# %%
#drop the historical column 
def clean_columns(df):
    df.columns = [column.replace(" ", "_").lower() for column in df.columns]

# %%
clean_columns(ev)

# %%
ev
# Out:
#          region    category           parameter  mode powertrain  year  \
# 0     Australia  Historical            EV sales  Cars        BEV  2011
# 1     Australia  Historical      EV stock share  Cars         EV  2011
# 2     Australia  Historical      EV sales share  Cars         EV  2011
# 3     Australia  Historical            EV stock  Cars        BEV  2011
# 4     Australia  Historical            EV stock  Cars        BEV  2012
# ...         ...         ...                 ...   ...        ...   ...
# 3793      World  Historical            EV stock  Cars        BEV  2023
# 3794      World  Historical            EV sales  Cars        BEV  2023
# 3795      World  Historical      EV sales share  Cars         EV  2023
# 3796      World  Historical      EV stock share  Cars         EV  2023
# 3797      World  Historical  Electricity demand  Cars         EV  2023
#
#           unit         value
# 0     Vehicles  4.900000e+01
# 1      percent  3.900000e-04
# ...

# %%
def drop_category (df):
    del df['category']

# %%
drop_category(ev)

# %%
ev
# Out:
#          region           parameter  mode powertrain  year      unit  \
# 0     Australia            EV sales  Cars        BEV  2011  Vehicles
# 1     Australia      EV stock share  Cars         EV  2011   percent
# 2     Australia      EV sales share  Cars         EV  2011   percent
# 3     Australia            EV stock  Cars        BEV  2011  Vehicles
# 4     Australia            EV stock  Cars        BEV  2012  Vehicles
# ...         ...                 ...   ...        ...   ...       ...
# 3793      World            EV stock  Cars        BEV  2023  Vehicles
# 3794      World            EV sales  Cars        BEV  2023  Vehicles
# 3795      World      EV sales share  Cars         EV  2023   percent
# 3796      World      EV stock share  Cars         EV  2023   percent
# 3797      World  Electricity demand  Cars         EV  2023       GWh
#
#              value
# 0     4.900000e+01
# 1     3.900000e-04
# 2     6.500000e-03
# 3     4.900000e+01
# 4     2.200000e+02
# ...

# %%
#drop the world row
def drop_world(df):
    df.drop(df[df['region'] == 'World'].index, inplace=True)

# %%
drop_world (ev)

# %%
ev
# Out:
#          region                      parameter  mode powertrain  year  \
# 0     Australia                       EV sales  Cars        BEV  2011
# 1     Australia                 EV stock share  Cars         EV  2011
# 2     Australia                 EV sales share  Cars         EV  2011
# 3     Australia                       EV stock  Cars        BEV  2011
# 4     Australia                       EV stock  Cars        BEV  2012
# ...         ...                            ...   ...        ...   ...
# 3639        USA           Oil displacement Mbd  Cars         EV  2023
# 3640        USA  Oil displacement, million lge  Cars         EV  2023
# 3641        USA                       EV sales  Cars       PHEV  2023
# 3642        USA                       EV stock  Cars       PHEV  2023
# 3643        USA             Electricity demand  Cars         EV  2023
#
#                                unit         value
# 0                          Vehicles  4.900000e+01
# ...

# %%
def keep_ev_sales(df):
    return df[df['parameter'] == 'EV sales']

# %%
keep_ev_sales(ev)
# Out:
#          region parameter  mode powertrain  year      unit      value
# 0     Australia  EV sales  Cars        BEV  2011  Vehicles       49.0
# 6     Australia  EV sales  Cars       PHEV  2012  Vehicles       80.0
# 9     Australia  EV sales  Cars        BEV  2012  Vehicles      170.0
# 10    Australia  EV sales  Cars        BEV  2013  Vehicles      190.0
# 13    Australia  EV sales  Cars       PHEV  2013  Vehicles      100.0
# ...         ...       ...   ...        ...   ...       ...        ...
# 3629        USA  EV sales  Cars       FCEV  2022  Vehicles     2700.0
# 3630        USA  EV sales  Cars        BEV  2022  Vehicles   800000.0
# 3635        USA  EV sales  Cars        BEV  2023  Vehicles  1100000.0
# 3636        USA  EV sales  Cars       FCEV  2023  Vehicles     3000.0
# 3641        USA  EV sales  Cars       PHEV  2023  Vehicles   290000.0
#
# [1300 rows x 7 columns]

# %%
ev_filtered = ev[["region","year", "value"]]

# %%
ev_filtered
# Out:
#          region  year         value
# 0     Australia  2011  4.900000e+01
# 1     Australia  2011  3.900000e-04
# 2     Australia  2011  6.500000e-03
# 3     Australia  2011  4.900000e+01
# 4     Australia  2012  2.200000e+02
# ...         ...   ...           ...
# 3639        USA  2023  1.700000e-01
# 3640        USA  2023  9.700000e+03
# 3641        USA  2023  2.900000e+05
# 3642        USA  2023  1.300000e+06
# 3643        USA  2023  2.200000e+04
#
# [3644 rows x 3 columns]

# %%
 ev_filtered= ev_filtered.rename(columns={"region": "country"})

# %%
 ev_filtered
# Out:
#         country  year         value
# 0     Australia  2011  4.900000e+01
# 1     Australia  2011  3.900000e-04
# 2     Australia  2011  6.500000e-03
# 3     Australia  2011  4.900000e+01
# 4     Australia  2012  2.200000e+02
# ...         ...   ...           ...
# 3639        USA  2023  1.700000e-01
# 3640        USA  2023  9.700000e+03
# 3641        USA  2023  2.900000e+05
# 3642        USA  2023  1.300000e+06
# 3643        USA  2023  2.200000e+04
#
# [3644 rows x 3 columns]

# %%
ev_filtered.to_csv("clean_ev_sales.csv")

# %%
co = pd.read_csv("co2_data/MtCO2_flat.csv")
co
# Out:
#            Country ISO 3166-1 alpha-3  Year         Total          Coal  \
# 0      Afghanistan                AFG  1750      0.000000           NaN
# 1      Afghanistan                AFG  1751      0.000000           NaN
# 2      Afghanistan                AFG  1752      0.000000           NaN
# 3      Afghanistan                AFG  1753      0.000000           NaN
# 4      Afghanistan                AFG  1754      0.000000           NaN
# ...            ...                ...   ...           ...           ...
# 63099       Global                WLD  2017  36096.739276  14506.973805
# 63100       Global                WLD  2018  36826.506600  14746.830688
# 63101       Global                WLD  2019  37082.558969  14725.978025
# 63102       Global                WLD  2020  35264.085734  14174.564010
# 63103       Global                WLD  2021  37123.850352  14979.598083
#
#                 Oil          Gas       Cement     Flaring       Other  \
# ...

# %%
co_pc = pd.read_csv("co2_data/CO2_percapita_flat.csv")
co_pc
# Out:
#            Country ISO 3166-1 alpha-3  Year     Total      Coal       Oil  \
# 0      Afghanistan                AFG  1750       NaN       NaN       NaN
# 1      Afghanistan                AFG  1751       NaN       NaN       NaN
# 2      Afghanistan                AFG  1752       NaN       NaN       NaN
# 3      Afghanistan                AFG  1753       NaN       NaN       NaN
# 4      Afghanistan                AFG  1754       NaN       NaN       NaN
# ...            ...                ...   ...       ...       ...       ...
# 63099       Global                WLD  2017  4.749682  1.908857  1.610910
# 63100       Global                WLD  2018  4.792753  1.919213  1.596350
# 63101       Global                WLD  2019  4.775633  1.896468  1.589920
# 63102       Global                WLD  2020  4.497423  1.807760  1.427353
# 63103       Global                WLD  2021  4.693699  1.893923  1.496614
#
#             Gas    Cement   Flaring     Other
# ...

# %%
ev["region"].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Brazil', 'Bulgaria', 'Canada',
#        'Chile', 'China', 'Colombia', 'Costa Rica', 'Croatia', 'Cyprus',
#        'Czech Republic', 'Denmark', 'Estonia', 'EU27', 'Europe',
#        'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland',
#        'India', 'Ireland', 'Israel', 'Italy', 'Japan', 'Korea', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Mexico', 'Netherlands', 'New Zealand',
#        'Norway', 'Poland', 'Portugal', 'Rest of the world', 'Romania',
#        'Seychelles', 'Slovakia', 'Slovenia', 'South Africa', 'Spain',
#        'Sweden', 'Switzerland', 'Turkiye', 'United Arab Emirates',
#        'United Kingdom', 'USA', 'World'], dtype=object)

# %%
co["Country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antarctica', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bonaire, Saint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cambodia', 'Canada', 'Cape Verde', 'Central African Republic',
#        'Chad', 'Chile', 'China', 'Christmas Island', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Côte d'Ivoire",
#        'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czech Republic',
#        'North Korea', 'Democratic Republic of the Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...
